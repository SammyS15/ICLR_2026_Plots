# %%
# === Metrics from Null Baseline ===

pokie_scores = [0.6720, 0.6710, 0.6742, 0.6685, 0.6738, 0.6746, 0.6710, 0.6697, 0.6715, 0.6713]
mmd_scores = [0.006395, 0.004265, 0.003403, 0.002788, 0.003426, 0.003280, 0.003802, 0.003695, 0.003016, 0.004785]
wasserstein_scores = [2.488233, 1.789892, 2.634524, 2.544850, 2.437570, 2.537348, 2.438836, 2.315358, 2.574840, 2.370399]

# === Compute Means ===
avg_pokie = sum(pokie_scores) / len(pokie_scores)
avg_mmd = sum(mmd_scores) / len(mmd_scores)
avg_wass = sum(wasserstein_scores) / len(wasserstein_scores)

# === Print Results ===
print(f"Average Pokie Score      : {avg_pokie:.4f}")
print(f"Average MMD Score        : {avg_mmd:.6f}")
print(f"Average Wasserstein Dist : {avg_wass:.6f}")
# Out:
# Average Pokie Score      : 0.6718
# Average MMD Score        : 0.003885
# Average Wasserstein Dist : 2.413185
