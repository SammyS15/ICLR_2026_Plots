# %%
# === Metrics from Conditional VAE ===

pokie_scores = [0.5757, 0.5978, 0.5456, 0.5711, 0.5654, 0.5508, 0.5877, 0.5838, 0.5554, 0.5830]
mmd_scores = [0.013771, 0.031416, 0.027700, 0.015088, 0.016395, 0.029934, 0.026164, 0.015618, 0.026317, 0.016789]
wasserstein_scores = [2.450646, 1.827495, 2.589609, 2.487475, 2.425975, 2.548357, 2.472069, 2.264512, 2.531690, 2.309099]

# === Compute Means ===
avg_pokie = sum(pokie_scores) / len(pokie_scores)
avg_mmd = sum(mmd_scores) / len(mmd_scores)
avg_wass = sum(wasserstein_scores) / len(wasserstein_scores)

# === Print Results ===
print(f"Average Pokie Score      : {avg_pokie:.4f}")
print(f"Average MMD Score        : {avg_mmd:.6f}")
print(f"Average Wasserstein Dist : {avg_wass:.6f}")
# Out:
# Average Pokie Score      : 0.5716
# Average MMD Score        : 0.021919
# Average Wasserstein Dist : 2.390693
